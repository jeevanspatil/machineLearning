# %% [markdown]
# # HW1: Decision Trees and Random Forests Programming Assignment
# ## Breast Cancer Dataset Analysis
#
# **Student Name:** _[Your Name Here]_
# **Date:** _[Date]_
#
# ---
#
# ## Instructions
#
# This notebook contains the programming assignment for HW1. You will analyze the Wisconsin Diagnostic Breast Cancer (WDBC) dataset using Decision Trees and Random Forests.
#
# ### Dataset Files
# - `wdbc.data` - The breast cancer dataset (569 samples, 30 features)
# - `wdbc.names` - Dataset documentation with feature descriptions
#
# ### Assignment Overview
# You will complete the following tasks:
# 1. Load and preprocess the breast cancer dataset
# 2. Calculate base rate of malignant cancer
# 3. Build and evaluate Decision Tree classifiers
# 4. Build and evaluate Random Forest classifiers
# 5. Compare models and analyze stability
#
# ### Submission Requirements
# - Complete all code cells with your implementation
# - Answer all questions in markdown cells
# - Ensure all cells run without errors
# - Create visualizations as requested
# - Submit as a `.zip` file under 10 MB
#
# ---

# %% [markdown]
# ## Setup: Import Required Libraries
#
# Import all necessary libraries for data manipulation, visualization, and machine learning.

# %%
# Import required libraries
# TODO: Import pandas, numpy, matplotlib.pyplot, seaborn
# TODO: Import DecisionTreeClassifier from sklearn.tree
# TODO: Import RandomForestClassifier from sklearn.ensemble
# TODO: Import cross_val_score from sklearn.model_selection
# TODO: Import Counter from collections

# Your code here

# %% [markdown]
# ## Data Loading and Preprocessing
#
# Load the breast cancer dataset from `wdbc.data` and parse it according to the specifications in `wdbc.names`.
#
# ### Data Format
# - Column 1: ID number
# - Column 2: Diagnosis (M = malignant, B = benign)
# - Columns 3-32: 30 real-valued features

# %%
# Define feature names
# TODO: Create a list of 30 feature names based on wdbc.names
# Hint: Features include mean, SE, and worst values of:
# radius, texture, perimeter, area, smoothness, compactness, 
# concavity, concave points, symmetry, fractal dimension

feature_names = [
    # Your code here
]

# %%
# Load the dataset
# TODO: Read wdbc.data using pandas
# TODO: Assign column names: 'id', 'diagnosis', and the 30 feature names
# TODO: Display first few rows and basic information

# Your code here

# %%
# Prepare features (X) and target (y)
# TODO: Extract feature columns into X
# TODO: Convert diagnosis to binary: M (malignant) = 1, B (benign) = 0
# TODO: Store result in y

# Your code here
X = None  # Replace with your code
y = None  # Replace with your code

# %% [markdown]
# ---
# ## Question 1: Base Rate of Malignant Cancer
#
# **Task:** Calculate the base rate (probability) of malignant cancer occurrence in the dataset.
#
# The base rate is the proportion of malignant cases (M) over the total number of cases.

# %%
# Calculate base rate
# TODO: Count number of malignant cases (y == 1)
# TODO: Calculate base rate as proportion of total cases
# TODO: Print the results

# Your code here
base_rate = None  # Replace with your calculation

print(f"Base rate of malignant cancer: {base_rate:.4f}")

# %%
# Visualize the class distribution
# TODO: Create a bar chart showing counts of Benign vs Malignant cases
# TODO: Add labels, title, and annotations

# Your code here

# %% [markdown]
# ---
# ## Question 2(a): Decision Tree Classifier Performance
#
# **Task:** Implement a DecisionTreeClassifier and evaluate it using:
# 1. Training on the entire dataset (full-dataset accuracy)
# 2. 10-fold cross-validation
#
# Vary `max_depth` from 1 to 10 and plot the results.
#
# ### Approach
# - For full-dataset accuracy: Train on all data and test on the same data
# - For cross-validation: Use 10-fold CV to estimate generalization performance

# %%
# Decision Tree with varying max_depth
# TODO: Create lists to store results
# TODO: Loop through max_depth values from 1 to 10
# TODO: For each depth:
#       - Create DecisionTreeClassifier with that max_depth and random_state=42
#       - Calculate full dataset accuracy (train and test on same data)
#       - Calculate 10-fold cross-validation scores
#       - Store mean and std of CV scores
# TODO: Print results in a table format

max_depths = range(1, 11)
full_dataset_scores = []
cv_scores_mean = []
cv_scores_std = []

# Your code here

# %%
# Plot the results
# TODO: Create a plot with:
#       - X-axis: max_depth (1 to 10)
#       - Y-axis: Accuracy
#       - Two lines: full dataset accuracy and 10-fold CV accuracy
#       - Error bars for CV accuracy (using std)
#       - Proper labels, title, and legend

# Your code here

# %% [markdown]
# ---
# ## Question 2(b): Optimal max_depth for Decision Tree
#
# **Task:** Identify the optimal `max_depth` settings based on:
# - **(i)** Full-dataset accuracy
# - **(ii)** 10-fold cross-validated accuracy

# %%
# Find optimal max_depth
# TODO: Find max_depth with highest full-dataset accuracy
# TODO: Find max_depth with highest cross-validation accuracy
# TODO: Print both results

# Your code here
best_depth_full = None  # Replace with your code
best_depth_cv = None    # Replace with your code

print(f"(i) Best max_depth for Full Dataset: {best_depth_full}")
print(f"(ii) Best max_depth for 10-Fold CV: {best_depth_cv}")

# %% [markdown]
# **Analysis:**
#
# _[Write your analysis here explaining the difference between full-dataset and CV accuracy]_

# %% [markdown]
# ---
# ## Question 3(a): Random Forest with Varying n_estimators
#
# **Task:** Use RandomForestClassifier with the optimal `max_depth` from Question 2(b)(ii) and vary `n_estimators` from 1 to 20.
#
# Plot the 10-fold cross-validated accuracy.

# %%
# Random Forest with varying n_estimators
# TODO: Use the optimal max_depth from Question 2(b)(ii)
# TODO: Loop through n_estimators from 1 to 20
# TODO: For each n_estimators:
#       - Create RandomForestClassifier with optimal max_depth and random_state=42
#       - Calculate 10-fold cross-validation scores
#       - Store mean and std
# TODO: Print results

optimal_depth_dt = best_depth_cv  # From Question 2(b)(ii)
n_estimators_range = range(1, 21)
rf_cv_scores_mean = []
rf_cv_scores_std = []

# Your code here

# %%
# Plot Random Forest performance
# TODO: Create a plot showing:
#       - RF accuracy vs n_estimators (with error bars)
#       - Horizontal line for best single Decision Tree (from Question 2)
#       - Proper labels, title, and legend

# Your code here

# %% [markdown]
# ---
# ## Question 3(b): Random Forest vs Single Decision Tree
#
# **Task:** Compare the performance of Random Forest to the single DecisionTreeClassifier.

# %%
# Compare Random Forest to Decision Tree
# TODO: Find best RF cross-validation accuracy
# TODO: Compare with best single DT accuracy from Question 2
# TODO: Calculate improvement (absolute and relative)
# TODO: Print comparison and conclusion

# Your code here

# %% [markdown]
# **Conclusion:**
#
# _[Write your conclusion about whether Random Forest shows noticeable improvement]_

# %% [markdown]
# ---
# ## Question 3(c): Optimal n_estimators
#
# **Task:** Identify the `n_estimators` value that gave the best cross-validated accuracy.

# %%
# Find optimal n_estimators
# TODO: Find n_estimators with highest CV accuracy
# TODO: Print the result

# Your code here
best_n_estimators = None  # Replace with your code

print(f"Best n_estimators: {best_n_estimators}")

# %% [markdown]
# ---
# ## Question 3(d): Random Forest with Varying max_depth
#
# **Task:** Fix `n_estimators` to the optimal value from 3(c) and vary `max_depth` from 1 to 10.
#
# Create a plot showing cross-validation accuracy over this range.

# %%
# Random Forest with varying max_depth
# TODO: Use optimal n_estimators from Question 3(c)
# TODO: Loop through max_depth from 1 to 10
# TODO: For each depth:
#       - Create RandomForestClassifier with optimal n_estimators
#       - Calculate 10-fold cross-validation scores
#       - Store mean and std
# TODO: Print results

optimal_n_estimators = best_n_estimators  # From Question 3(c)
max_depths_rf = range(1, 11)
rf_depth_cv_scores_mean = []
rf_depth_cv_scores_std = []

# Your code here

# %%
# Plot Random Forest with varying max_depth
# TODO: Create a plot showing RF accuracy vs max_depth
#       - Include error bars
#       - Add proper labels, title, and legend

# Your code here

# %% [markdown]
# ---
# ## Question 3(e): Compare Optimal max_depth Settings
#
# **Task:** Compare the optimal `max_depth` from 3(d) with the one from 2(b)(ii) and explain any differences.

# %%
# Compare optimal max_depth settings
# TODO: Find optimal max_depth for RF from Question 3(d)
# TODO: Compare with optimal max_depth for DT from Question 2(b)(ii)
# TODO: Print comparison

# Your code here
best_depth_rf = None  # Replace with your code

print(f"Optimal max_depth for Single Decision Tree [2(b)(ii)]: {optimal_depth_dt}")
print(f"Optimal max_depth for Random Forest [3(d)]: {best_depth_rf}")

# %% [markdown]
# **Explanation:**
#
# _[Explain why the optimal max_depth values differ or are the same between single DT and RF]_
#
# _Consider factors like:_
# - _Ensemble averaging and overfitting_
# - _Bootstrap sampling_
# - _Feature randomness_
# - _Model complexity vs generalization_

# %% [markdown]
# ---
# ## Question 4(a): Optimal max_depth Distribution Across Random States
#
# **Task:** Generate a bar chart showing the distribution of optimal `max_depth` settings for 100 different random states (0-99).
#
# For each random state, find the best `max_depth` based on 10-fold CV accuracy.

# %%
# Optimal max_depth for 100 random states
# TODO: Loop through random states 0 to 99
# TODO: For each random state:
#       - Test max_depth values 1 to 10
#       - Find the depth with best 10-fold CV accuracy
#       - Store the optimal depth
# TODO: Count frequency of each optimal depth
# Note: This may take a few minutes to run

random_states = range(100)
optimal_depths_distribution = []

# Your code here

# %%
# Create bar chart
# TODO: Count frequency of each optimal max_depth
# TODO: Create bar chart showing:
#       - X-axis: max_depth values
#       - Y-axis: Frequency (out of 100)
#       - Value labels on bars
#       - Proper title and labels

# Your code here

# %% [markdown]
# ---
# ## Question 4(b): Top Two Most Frequent max_depth Settings
#
# **Task:** Identify the top two most frequently chosen `max_depth` parameter settings from Question 4(a).

# %%
# Find top two most frequent max_depth values
# TODO: Find the two most common max_depth values
# TODO: Print their frequencies
# TODO: Provide interpretation

# Your code here

# %% [markdown]
# **Interpretation:**
#
# _[Explain what the most frequent max_depth values suggest about model stability]_

# %% [markdown]
# ---
# ## Summary and Conclusions
#
# **Task:** Summarize your key findings from this assignment.
#
# Include:
# 1. Base rate findings
# 2. Decision Tree performance and optimal settings
# 3. Random Forest improvements
# 4. Comparison between single trees and ensembles
# 5. Stability analysis insights
# 6. Recommendations for this classification task

# %% [markdown]
# ### Key Findings:
#
# _[Write your summary here]_
#
# 1. **Base Rate:**
#
# 2. **Decision Tree Analysis:**
#
# 3. **Random Forest Improvements:**
#
# 4. **Depth Comparison:**
#
# 5. **Stability Analysis:**
#
# ### Recommendations:
#
# _[Provide your recommendations]_
